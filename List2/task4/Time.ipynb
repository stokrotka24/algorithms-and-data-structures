# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10')
x = shelf_file['x']
t_insert = shelf_file['t_insert']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 10, int")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_insert, color="green", label="insertion")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 10, int")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10_str')
x = shelf_file['x']
t_insert = shelf_file['t_insert']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 10, str")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_insert, color="green", label="insertion")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10_str')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 10, str")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 100, int")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 100, int")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100_str')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_quick = shelf_file['t_quick']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 100, str")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_quick, color="red", label="quick")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100_str')
x = shelf_file['x']
t_merge = shelf_file['t_merge']
t_hybrid = shelf_file['t_hybrid']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time, k = 100, str")
plt.xlabel("n")
plt.ylabel("t(n)  [seconds]")
plt.plot(x, t_merge, color="blue", label="merge")
plt.plot(x, t_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()
