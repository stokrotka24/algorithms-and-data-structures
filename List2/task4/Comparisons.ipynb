# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10')
x = shelf_file['x']
c_insert = shelf_file['c_insert']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 10, int")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_insert, color="green", label="insertion")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 10, int")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10_str')
x = shelf_file['x']
c_insert = shelf_file['c_insert']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 10, str")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_insert, color="green", label="insertion")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k10_str')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 10, str")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 100, int")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 100, int")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100_str')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_quick = shelf_file['c_quick']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 100, str")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_quick, color="red", label="quick")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('parsed_k100_str')
x = shelf_file['x']
c_merge = shelf_file['c_merge']
c_hybrid = shelf_file['c_hybrid']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons, k = 100, str")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_merge, color="blue", label="merge")
plt.plot(x, c_hybrid, color="orange", label="hybrid")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()
