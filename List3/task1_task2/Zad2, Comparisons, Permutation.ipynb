# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_3_k_small')
x = shelf_file['x']
avgs_3 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_5_k_small')
avgs_5 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_7_k_small')
avgs_7 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_9_k_small')
avgs_9 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_11_k_small')
avgs_11 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_13_k_small')
avgs_13 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_15_k_small')
avgs_15 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_17_k_small')
avgs_17 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_19_k_small')
avgs_19 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_21_k_small')
avgs_21 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_23_k_small')
avgs_23 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_25_k_small')
avgs_25 = shelf_file['avgs']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 15))
plt.title("Comparisons for select for different group sizes, k small")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, avgs_3, color="#a7b4ff", label="size 3")
plt.plot(x, avgs_5, color="#cd025c", label="size 5")
plt.plot(x, avgs_7, color="#0055ff", label="size 7")
plt.plot(x, avgs_9, color="#ff9300", label="size 9")
plt.plot(x, avgs_11, color="#39224f", label="size 11")
plt.plot(x, avgs_13, color="#39ac39", label="size 13")
plt.plot(x, avgs_15, color="#990099", label="size 15")
plt.plot(x, avgs_17, color="#ffff00", label="size 17")
plt.plot(x, avgs_19, color="#ff3300", label="size 19")
plt.plot(x, avgs_21, color="#006400", label="size 21")
plt.plot(x, avgs_23, color="#fa8072", label="size 23")
plt.plot(x, avgs_25, color="#000000", label="size 25")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_3_k_medium')
x = shelf_file['x']
avgs_3 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_5_k_medium')
avgs_5 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_7_k_medium')
avgs_7 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_9_k_medium')
avgs_9 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_11_k_medium')
avgs_11 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_13_k_medium')
avgs_13 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_15_k_medium')
avgs_15 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_17_k_medium')
avgs_17 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_19_k_medium')
avgs_19 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_21_k_medium')
avgs_21 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_23_k_medium')
avgs_23 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_25_k_medium')
avgs_25 = shelf_file['avgs']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 15))
plt.title("Comparisons for select for different group sizes, k medium")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, avgs_3, color="#a7b4ff", label="size 3")
plt.plot(x, avgs_5, color="#cd025c", label="size 5")
plt.plot(x, avgs_7, color="#0055ff", label="size 7")
plt.plot(x, avgs_9, color="#ff9300", label="size 9")
plt.plot(x, avgs_11, color="#39224f", label="size 11")
plt.plot(x, avgs_13, color="#39ac39", label="size 13")
plt.plot(x, avgs_15, color="#990099", label="size 15")
plt.plot(x, avgs_17, color="#ffff00", label="size 17")
plt.plot(x, avgs_19, color="#ff3300", label="size 19")
plt.plot(x, avgs_21, color="#006400", label="size 21")
plt.plot(x, avgs_23, color="#fa8072", label="size 23")
plt.plot(x, avgs_25, color="#000000", label="size 25")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_3_k_big')
x = shelf_file['x']
avgs_3 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_5_k_big')
avgs_5 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_7_k_big')
avgs_7 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_9_k_big')
avgs_9 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_11_k_big')
avgs_11 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_13_k_big')
avgs_13 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_15_k_big')
avgs_15 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_17_k_big')
avgs_17 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_19_k_big')
avgs_19 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_21_k_big')
avgs_21 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_23_k_big')
avgs_23 = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results_zad2/comp/permutation_group_25_k_big')
avgs_25 = shelf_file['avgs']
shelf_file.close()


plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 15))
plt.title("Comparisons for select for different group sizes, k big")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, avgs_3, color="#a7b4ff", label="size 3")
plt.plot(x, avgs_5, color="#cd025c", label="size 5")
plt.plot(x, avgs_7, color="#0055ff", label="size 7")
plt.plot(x, avgs_9, color="#ff9300", label="size 9")
plt.plot(x, avgs_11, color="#39224f", label="size 11")
plt.plot(x, avgs_13, color="#39ac39", label="size 13")
plt.plot(x, avgs_15, color="#990099", label="size 15")
plt.plot(x, avgs_17, color="#ffff00", label="size 17")
plt.plot(x, avgs_19, color="#ff3300", label="size 19")
plt.plot(x, avgs_21, color="#006400", label="size 21")
plt.plot(x, avgs_23, color="#fa8072", label="size 23")
plt.plot(x, avgs_25, color="#000000", label="size 25")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
