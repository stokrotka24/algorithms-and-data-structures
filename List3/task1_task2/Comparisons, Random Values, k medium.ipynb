# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_medium')
x = shelf_file['x']
avgs = shelf_file['avgs']
stddevs = shelf_file['stddevs']
points_x = shelf_file['points_x']
points_y = shelf_file['points_y']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.scatter(points_x, points_y, color="pink")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_medium')
x = shelf_file['x']
mins = shelf_file['mins']
avgs = shelf_file['avgs']
maxs = shelf_file['maxs']
stddevs = shelf_file['stddevs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, mins, color="green", label="minimum")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, maxs, color="red", label="maximum")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_medium')
x = shelf_file['x']
mins = shelf_file['mins']
avgs = shelf_file['avgs']
maxs = shelf_file['maxs']
stddevs = shelf_file['stddevs']
points_x = shelf_file['points_x']
points_y = shelf_file['points_y']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, mins, color="green", label="minimum")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, maxs, color="red", label="maximum")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.scatter(points_x, points_y, color="pink")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_medium')
x = shelf_file['x']
avgs = shelf_file['avgs']
stddevs = shelf_file['stddevs']
points_x = shelf_file['points_x']
points_y = shelf_file['points_y']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.scatter(points_x, points_y, color="pink")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_medium')
x = shelf_file['x']
mins = shelf_file['mins']
avgs = shelf_file['avgs']
maxs = shelf_file['maxs']
stddevs = shelf_file['stddevs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, mins, color="green", label="minimum")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, maxs, color="red", label="maximum")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_medium')
x = shelf_file['x']
mins = shelf_file['mins']
avgs = shelf_file['avgs']
maxs = shelf_file['maxs']
stddevs = shelf_file['stddevs']
points_x = shelf_file['points_x']
points_y = shelf_file['points_y']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, mins, color="green", label="minimum")
plt.plot(x, avgs, color="blue", label="average")
plt.plot(x, maxs, color="red", label="maximum")
plt.plot(x, avgs-stddevs, color="orange", label="average +- stddev")
plt.plot(x, avgs+stddevs, color="orange")
plt.legend(loc="upper left")
plt.scatter(points_x, points_y, color="pink")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_medium')
x = shelf_file['x']
r_mins = shelf_file['mins']
r_avgs = shelf_file['avgs']
r_maxs = shelf_file['maxs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_medium')
s_mins = shelf_file['mins']
s_avgs = shelf_file['avgs']
s_maxs = shelf_file['maxs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select and select")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, s_mins, color="yellow", label="minimum select")
plt.plot(x, s_avgs, color="cyan", label="average select")
plt.plot(x, s_maxs, color="magenta", label="maximum select")
plt.plot(x, r_mins, color="green", label="minimum randomized select")
plt.plot(x, r_avgs, color="blue", label="average randomized select")
plt.plot(x, r_maxs, color="red", label="maximum randomized select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()
