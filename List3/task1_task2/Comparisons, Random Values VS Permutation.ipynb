# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_small')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_randomized_select_k_small')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select, k small")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_medium')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_randomized_select_k_medium')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select, k medium")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_randomized_select_k_big')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_randomized_select_k_big')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for randomized select, k big")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_small')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_select_k_small')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select, k small")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_medium')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_select_k_medium')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select, k medium")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import numpy as np
import shelve

shelf_file = shelve.open('parsed_results/comp/random_values_select_k_big')
x = shelf_file['x']
r_avgs = shelf_file['avgs']
shelf_file.close()

shelf_file = shelve.open('parsed_results/comp/permutation_select_k_big')
p_avgs = shelf_file['avgs']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for select, k big")
plt.xlabel("n")
plt.ylabel("comparisons")
plt.plot(x, r_avgs, color="yellow", label="random values")
plt.plot(x, p_avgs, color="cyan", label="permutation")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()
