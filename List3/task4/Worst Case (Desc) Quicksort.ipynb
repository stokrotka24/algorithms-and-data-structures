# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_quick = shelf_file['c_quick']
c_s_quick = shelf_file['c_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for array [n, n-1, ..., 1]")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_quick, color="red", label="quicksort")
plt.plot(x, c_s_quick, color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_quick = shelf_file['c_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons (for array [n, n-1, ..., 1]) per n")
plt.xlabel("n")
plt.ylabel("c(n)/n")
plt.plot(x, c_quick/x, color="red", label="quicksort")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_quick = shelf_file['c_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons (for array [n, n-1, ..., 1]) per n^2")
plt.xlabel("n")
plt.ylabel("c(n)/n^2")
plt.plot(x, c_quick/(x*x), color="red", label="quicksort")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_s_quick = shelf_file['c_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons for array [n, n-1, ..., 1]")
plt.xlabel("n")
plt.ylabel("c(n)")
plt.plot(x, c_s_quick, color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_s_quick = shelf_file['c_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons (for array [n, n-1, ..., 1]) per n")
plt.xlabel("n")
plt.ylabel("c(n)/n")
plt.plot(x, c_s_quick/x, color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
c_s_quick = shelf_file['c_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Comparisons (for array [n, n-1, ..., 1]) per n * log(n)")
plt.xlabel("n")
plt.ylabel("c(n)/(n*log(n)")
plt.plot(x, c_s_quick/(x * np.log(x)), color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
t_quick = shelf_file['t_quick']
t_s_quick = shelf_file['t_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time for array [n, n-1, ..., 1]")
plt.xlabel("n")
plt.ylabel("t(n) [seconds]")
plt.plot(x, t_quick, color="red", label="quicksort")
plt.plot(x, t_s_quick, color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import shelve
# %matplotlib inline


shelf_file = shelve.open('worst_desc_parsed_results')
x = shelf_file['x']
t_s_quick = shelf_file['t_s_quick']
shelf_file.close()

plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(15, 10))
plt.title("Time for array [n, n-1, ..., 1]")
plt.xlabel("n")
plt.ylabel("t(n) [seconds]")
plt.plot(x, t_s_quick, color="purple", label="quicksort with select")
plt.legend(loc="upper left")
plt.grid(True)
plt.show()
